# %%
import re

# %%
from IPython.display import display, HTML
import os
import psycopg2
import json
import pandas as pd


conn = psycopg2.connect(
    host="localhost",
    database="tpch5gb",
    user="postgres",
    password="qwer1234")
print(conn)
cur = conn.cursor()
# Out:
# <connection object at 0x7faa8e02e700; dsn: 'user=postgres password=xxx dbname=tpch5gb host=localhost', closed: 0>

# %%
#We converting json execution plan from postgres to indexed list of all nodes + marking their parent nodes
#using Breadth First Search algorithm
def bfs(node, node_id):
    visited = []
    queue = []
    node['parent'] = None
    queue.append(node)
    while queue:
        m = queue.pop(0)
        
        #Proceed possible filter and group_by field via creating extra node
        #We assume, that if both of them are present, filtering is taking place after grouping operation
        #(Filter --> GroupBy equals Filter after GroupBy, because of tree(child node --> parent node) structure)
        if "Filter" in m and "Group Key" in m:
            print("tut naw variant")
            visited.append({"operator":"Filter", "id":node_id, "parent":m["parent"]})
            node_id += 1
            visited.append({"operator":m['Node Type'], "id":node_id, "parent":node_id-1})
            node_id += 1
            p_node = {"operator":"GroupBy", "id":node_id, "parent":node_id-1}
            visited.append(p_node)
        
        elif "Filter" in m:
                #p_node['extra_node'] = "Filter"
                visited.append({"operator":"Filter", "id":node_id, "parent":m["parent"]})
                node_id += 1 
                p_node = {"operator":m['Node Type'], "id":node_id, "parent":node_id-1}
                visited.append(p_node)
        
        elif "Group Key" in m:
                #p_node['extra_node'] = "GroupBy"
                visited.append({"operator":m['Node Type'], "id":node_id, "parent":m["parent"]})
                node_id += 1
                p_node = {"operator":"GroupBy", "id":node_id, "parent":node_id-1}
                visited.append(p_node)
        else:
            p_node = {"operator":m['Node Type'], "id":node_id, "parent":m["parent"]}
            visited.append(p_node)
                
        if "Plans" in m:
            for child in m['Plans']:
                child['parent'] = node_id
                queue.append(child)
        node_id += 1
    print(*visited, sep="\n")
    return visited
    #print(*visited, sep="\n")
    
#Flipping node list via converting child nodes to predecessors
#This structure is essential for DataFarm Unified Json Input
def flip_bfs(exec_plan):
    #create predecessors list
    for node in exec_plan:
        node['predecessors'] = []
    for node in exec_plan:
        if node.get("parent") is not None:
            parent = next(item for item in exec_plan if item["id"] == node.get("parent"))
            parent['predecessors'].append(node['id'])
            del node['parent']
        else:
            del node['parent']
    #append DataSink
    exec_plan.insert(0,{"operator":"Data Sink", "id":0, "predecessors":[1]})
    return exec_plan
    #print(*exec_plan, sep="\n")
    
#Completing unified json and saving
def complete_and_save(exec_plan_flipped):
    for node in exec_plan_flipped:
        if not node['predecessors']:
            node["type"] = "Data Source"
        elif node['id'] == 0:
            node["type"] = "sink"
        else:
            node["type"] = "operator"
        
        for count, value in enumerate(node['predecessors']):
            node['predecessors'][count] = {"id" : value}
        
        if not node['predecessors']:
            del node['predecessors']
    unified_json = {"executionPlan" : {"nodes" : exec_plan_flipped}}
    return unified_json

# %%
directory = 'sqls'
output_dir = 'unified_input'
 
# iterate over files in
# that directory
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # checking if it is a file
    if os.path.isfile(f):# and filename == 'q11':
        sql = open(f, "r")
        cur = conn.cursor()
        cur.execute("EXPLAIN (FORMAT JSON)" + sql.read())
        plan = cur.fetchone()[0][0].get("Plan")
        print("Query ", f)
        unified_json = complete_and_save(flip_bfs(bfs(plan, 1)))
        #print(unified_json)
        with open(os.path.join(output_dir,'TPC_H_' + filename + 'Unified.json'), 'w', encoding='utf-8') as nf:
            json.dump(unified_json, nf, ensure_ascii=False, indent=2)
# Out:
# Query  sqls/q11
# tut naw variant
# {'operator': 'Sort', 'id': 1, 'parent': None}
# {'operator': 'Aggregate', 'id': 2, 'parent': 1}
# {'operator': 'Filter', 'id': 3, 'parent': 1}
# {'operator': 'Aggregate', 'id': 4, 'parent': 3}
# {'operator': 'GroupBy', 'id': 5, 'parent': 4}
# {'operator': 'Gather', 'id': 6, 'parent': 2}
# {'operator': 'Gather', 'id': 7, 'parent': 5}
# {'operator': 'Aggregate', 'id': 8, 'parent': 6}
# {'operator': 'Aggregate', 'id': 9, 'parent': 7}
# {'operator': 'GroupBy', 'id': 10, 'parent': 9}
# {'operator': 'Hash Join', 'id': 11, 'parent': 8}
# {'operator': 'Hash Join', 'id': 12, 'parent': 10}
# {'operator': 'Seq Scan', 'id': 13, 'parent': 11}
# {'operator': 'Hash', 'id': 14, 'parent': 11}
# {'operator': 'Seq Scan', 'id': 15, 'parent': 12}
# {'operator': 'Hash', 'id': 16, 'parent': 12}
# {'operator': 'Hash Join', 'id': 17, 'parent': 14}
# {'operator': 'Hash Join', 'id': 18, 'parent': 16}
# {'operator': 'Seq Scan', 'id': 19, 'parent': 17}
# {'operator': 'Hash', 'id': 20, 'parent': 17}
# {'operator': 'Seq Scan', 'id': 21, 'parent': 18}
# {'operator': 'Hash', 'id': 22, 'parent': 18}
# {'operator': 'Filter', 'id': 23, 'parent': 20}
# {'operator': 'Seq Scan', 'id': 24, 'parent': 23}
# {'operator': 'Filter', 'id': 25, 'parent': 22}
# {'operator': 'Seq Scan', 'id': 26, 'parent': 25}
# Query  sqls/q3
# {'operator': 'Limit', 'id': 1, 'parent': None}
# {'operator': 'Sort', 'id': 2, 'parent': 1}
# {'operator': 'Aggregate', 'id': 3, 'parent': 2}
# {'operator': 'GroupBy', 'id': 4, 'parent': 3}
# {'operator': 'Gather Merge', 'id': 5, 'parent': 4}
# {'operator': 'Aggregate', 'id': 6, 'parent': 5}
# {'operator': 'GroupBy', 'id': 7, 'parent': 6}
# {'operator': 'Sort', 'id': 8, 'parent': 7}
# {'operator': 'Hash Join', 'id': 9, 'parent': 8}
# {'operator': 'Filter', 'id': 10, 'parent': 9}
# {'operator': 'Seq Scan', 'id': 11, 'parent': 10}
# {'operator': 'Hash', 'id': 12, 'parent': 9}
# {'operator': 'Hash Join', 'id': 13, 'parent': 12}
# {'operator': 'Filter', 'id': 14, 'parent': 13}
# {'operator': 'Seq Scan', 'id': 15, 'parent': 14}
# {'operator': 'Hash', 'id': 16, 'parent': 13}
# {'operator': 'Filter', 'id': 17, 'parent': 16}
# {'operator': 'Seq Scan', 'id': 18, 'parent': 17}
# Query  sqls/q1
# {'operator': 'Aggregate', 'id': 1, 'parent': None}
# {'operator': 'GroupBy', 'id': 2, 'parent': 1}
# {'operator': 'Gather Merge', 'id': 3, 'parent': 2}
# {'operator': 'Sort', 'id': 4, 'parent': 3}
# {'operator': 'Aggregate', 'id': 5, 'parent': 4}
# {'operator': 'GroupBy', 'id': 6, 'parent': 5}
# {'operator': 'Filter', 'id': 7, 'parent': 6}
# {'operator': 'Seq Scan', 'id': 8, 'parent': 7}
# Query  sqls/q13
# {'operator': 'Sort', 'id': 1, 'parent': None}
# {'operator': 'Aggregate', 'id': 2, 'parent': 1}
# {'operator': 'GroupBy', 'id': 3, 'parent': 2}
# {'operator': 'Aggregate', 'id': 4, 'parent': 3}
# {'operator': 'GroupBy', 'id': 5, 'parent': 4}
# {'operator': 'Hash Join', 'id': 6, 'parent': 5}
# {'operator': 'Filter', 'id': 7, 'parent': 6}
# {'operator': 'Seq Scan', 'id': 8, 'parent': 7}
# {'operator': 'Hash', 'id': 9, 'parent': 6}
# {'operator': 'Seq Scan', 'id': 10, 'parent': 9}
# Query  sqls/q17
# {'operator': 'Aggregate', 'id': 1, 'parent': None}
# {'operator': 'Hash Join', 'id': 2, 'parent': 1}
# {'operator': 'Seq Scan', 'id': 3, 'parent': 2}
# {'operator': 'Hash', 'id': 4, 'parent': 2}
# {'operator': 'Aggregate', 'id': 5, 'parent': 2}
# {'operator': 'Gather', 'id': 6, 'parent': 4}
# {'operator': 'Filter', 'id': 7, 'parent': 5}
# {'operator': 'Seq Scan', 'id': 8, 'parent': 7}
# {'operator': 'Filter', 'id': 9, 'parent': 6}
# {'operator': 'Seq Scan', 'id': 10, 'parent': 9}
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In [4], line 12
#      10 sql = open(f, "r")
#      11 cur = conn.cursor()
# ---> 12 cur.execute("EXPLAIN (FORMAT JSON)" + sql.read())
#      13 plan = cur.fetchone()[0][0].get("Plan")
#      14 print("Query ", f)
#
# File /usr/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
#     319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
# --> 322     (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323     # keep undecoded input until the next call
#     324     self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc8 in position 43: invalid continuation byte

# %%
cur.close()
conn.close()
